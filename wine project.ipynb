# %%
import pandas as pd
import numpy as np
from sklearn.decomposition import PCA
from matplotlib import pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("wine.csv")
data
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0       1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1       1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2       1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3       1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4       1    13.24        2.59  2.87  21.0  118     2.80        2.69
# ..    ...      ...         ...   ...   ...  ...      ...         ...
# 173     3    13.71        5.65  2.45  20.5   95     1.68        0.61
# 174     3    13.40        3.91  2.48  23.0  102     1.80        0.75
# 175     3    13.27        4.28  2.26  20.0  120     1.59        0.69
# 176     3    13.17        2.59  2.37  20.0  120     1.65        0.68
# 177     3    14.13        4.10  2.74  24.5   96     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                    0.28     2.29       5.64  1.04  3.92     1065
# 1                    0.26     1.28       4.38  1.05  3.40     1050
# 2                    0.30     2.81       5.68  1.03  3.17     1185
# 3                    0.24     2.18       7.80  0.86  3.45     1480
# 4                    0.39     1.82       4.32  1.04  2.93      735
# ..                    ...      ...        ...   ...   ...      ...
# 173                  0.52     1.06       7.70  0.64  1.74      740
# 174                  0.43     1.41       7.30  0.70  1.56      750
# 175                  0.43     1.35      10.20  0.59  1.56      835
# 176                  0.53     1.46       9.30  0.60  1.62      840
# 177                  0.56     1.35       9.20  0.61  1.60      560
#
# [178 rows x 14 columns]

# %%
#lets check the null values
data.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %%
#Lets check datatypes of the columns
data.dtypes
# Out:
# Wine                      int64
# Alcohol                 float64
# Malic.acid              float64
# Ash                     float64
# Acl                     float64
# Mg                        int64
# Phenols                 float64
# Flavanoids              float64
# Nonflavanoid.phenols    float64
# Proanth                 float64
# Color.int               float64
# Hue                     float64
# OD                      float64
# Proline                   int64
# dtype: object

# %%
#Lets check the correlation matrix
data.corr()
# Out:
#                           Wine   Alcohol  Malic.acid       Ash       Acl  \
# Wine                  1.000000 -0.328222    0.437776 -0.049643  0.517859
# Alcohol              -0.328222  1.000000    0.094397  0.211545 -0.310235
# Malic.acid            0.437776  0.094397    1.000000  0.164045  0.288500
# Ash                  -0.049643  0.211545    0.164045  1.000000  0.443367
# Acl                   0.517859 -0.310235    0.288500  0.443367  1.000000
# Mg                   -0.209179  0.270798   -0.054575  0.286587 -0.083333
# Phenols              -0.719163  0.289101   -0.335167  0.128980 -0.321113
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077 -0.351370
# Nonflavanoid.phenols  0.489109 -0.155929    0.292977  0.186230  0.361922
# Proanth              -0.499130  0.136698   -0.220746  0.009652 -0.197327
# Color.int             0.265668  0.546364    0.248985  0.258887  0.018732
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667 -0.273955
# OD                   -0.788230  0.072343   -0.368710  0.003911 -0.276769
# Proline              -0.633717  0.643720   -0.192011  0.223626 -0.440597
#
#                             Mg   Phenols  Flavanoids  Nonflavanoid.phenols  \
# Wine                 -0.209179 -0.719163   -0.847498              0.489109
# Alcohol               0.270798  0.289101    0.236815             -0.155929
# Malic.acid           -0.054575 -0.335167   -0.411007              0.292977
# Ash                   0.286587  0.128980    0.115077              0.186230
# Acl                  -0.083333 -0.321113   -0.351370              0.361922
# Mg                    1.000000  0.214401    0.195784             -0.256294
# Phenols               0.214401  1.000000    0.864564             -0.449935
# Flavanoids            0.195784  0.864564    1.000000             -0.537900
# Nonflavanoid.phenols -0.256294 -0.449935   -0.537900              1.000000
# Proanth               0.236441  0.612413    0.652692             -0.365845
# Color.int             0.199950 -0.055136   -0.172379              0.139057
# Hue                   0.055398  0.433681    0.543479             -0.262640
# OD                    0.066004  0.699949    0.787194             -0.503270
# Proline               0.393351  0.498115    0.494193             -0.311385
#
#                        Proanth  Color.int       Hue        OD   Proline
# Wine                 -0.499130   0.265668 -0.617369 -0.788230 -0.633717
# Alcohol               0.136698   0.546364 -0.071747  0.072343  0.643720
# Malic.acid           -0.220746   0.248985 -0.561296 -0.368710 -0.192011
# Ash                   0.009652   0.258887 -0.074667  0.003911  0.223626
# Acl                  -0.197327   0.018732 -0.273955 -0.276769 -0.440597
# Mg                    0.236441   0.199950  0.055398  0.066004  0.393351
# Phenols               0.612413  -0.055136  0.433681  0.699949  0.498115
# Flavanoids            0.652692  -0.172379  0.543479  0.787194  0.494193
# Nonflavanoid.phenols -0.365845   0.139057 -0.262640 -0.503270 -0.311385
# Proanth               1.000000  -0.025250  0.295544  0.519067  0.330417
# Color.int            -0.025250   1.000000 -0.521813 -0.428815  0.316100
# Hue                   0.295544  -0.521813  1.000000  0.565468  0.236183
# OD                    0.519067  -0.428815  0.565468  1.000000  0.312761
# Proline               0.330417   0.316100  0.236183  0.312761  1.000000

# %%
#Lets descrine the matrix
data.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# std      0.625851    0.998859              0.124453    0.572359    2.318286
# min      0.980000    0.340000              0.130000    0.410000    1.280000
# 25%      1.742500    1.205000              0.270000    1.250000    3.220000
# 50%      2.355000    2.135000              0.340000    1.555000    4.690000
# 75%      2.800000    2.875000              0.437500    1.950000    6.200000
# max      3.880000    5.080000              0.660000    3.580000   13.000000
#
#               Hue          OD      Proline
# count  178.000000  178.000000   178.000000
# mean     0.957449    2.611685   746.893258
# std      0.228572    0.709990   314.907474
# min      0.480000    1.270000   278.000000
# 25%      0.782500    1.937500   500.500000
# 50%      0.965000    2.780000   673.500000
# 75%      1.120000    3.170000   985.000000
# max      1.710000    4.000000  1680.000000

# %%
#lets check the skewness of the dataset
data.skew()
#there is some skewness which needs to be treated
# Out:
# Wine                    0.107431
# Alcohol                -0.051482
# Malic.acid              1.039651
# Ash                    -0.176699
# Acl                     0.213047
# Mg                      1.098191
# Phenols                 0.086639
# Flavanoids              0.025344
# Nonflavanoid.phenols    0.450151
# Proanth                 0.517137
# Color.int               0.868585
# Hue                     0.021091
# OD                     -0.307285
# Proline                 0.767822
# dtype: float64

# %%
#Treating using log
import numpy as np
for col in data.columns:
    if data.skew().loc[col]>0.55:
        data[col]=np.log1p(data[col])

# %%
#Lets again check the skewness
data.skew()
# Out:
# Wine                    0.107431
# Alcohol                -0.051482
# Malic.acid              0.529222
# Ash                    -0.176699
# Acl                     0.213047
# Mg                      0.605723
# Phenols                 0.086639
# Flavanoids              0.025344
# Nonflavanoid.phenols    0.450151
# Proanth                 0.517137
# Color.int               0.097222
# Hue                     0.021091
# OD                     -0.307285
# Proline                 0.087930
# dtype: float64

# %%
data
# Out:
#      Wine  Alcohol  Malic.acid   Ash   Acl        Mg  Phenols  Flavanoids  \
# 0       1    14.23    0.996949  2.43  15.6  4.852030     2.80        3.06
# 1       1    13.20    1.022451  2.14  11.2  4.615121     2.65        2.76
# 2       1    13.16    1.211941  2.67  18.6  4.624973     2.80        3.24
# 3       1    14.37    1.081805  2.50  16.8  4.736198     3.85        3.49
# 4       1    13.24    1.278152  2.87  21.0  4.779123     2.80        2.69
# ..    ...      ...         ...   ...   ...       ...      ...         ...
# 173     3    13.71    1.894617  2.45  20.5  4.564348     1.68        0.61
# 174     3    13.40    1.591274  2.48  23.0  4.634729     1.80        0.75
# 175     3    13.27    1.663926  2.26  20.0  4.795791     1.59        0.69
# 176     3    13.17    1.278152  2.37  20.0  4.795791     1.65        0.68
# 177     3    14.13    1.629241  2.74  24.5  4.574711     2.05        0.76
#
#      Nonflavanoid.phenols  Proanth  Color.int   Hue    OD   Proline
# 0                    0.28     2.29   1.893112  1.04  3.92  6.971669
# 1                    0.26     1.28   1.682688  1.05  3.40  6.957497
# 2                    0.30     2.81   1.899118  1.03  3.17  7.078342
# 3                    0.24     2.18   2.174752  0.86  3.45  7.300473
# 4                    0.39     1.82   1.671473  1.04  2.93  6.601230
# ..                    ...      ...        ...   ...   ...       ...
# 173                  0.52     1.06   2.163323  0.64  1.74  6.608001
# 174                  0.43     1.41   2.116256  0.70  1.56  6.621406
# 175                  0.43     1.35   2.415914  0.59  1.56  6.728629
# 176                  0.53     1.46   2.332144  0.60  1.62  6.734592
# 177                  0.56     1.35   2.322388  0.61  1.60  6.329721
#
# [178 rows x 14 columns]

# %%
#Lets check pairplot using seaborn library
#import seaborn as sns
#sns.pairplot(data)
#plt.show()

# %%
#Lets check for outliers
from scipy.stats import zscore
z_score=abs(zscore(data))
print(data.shape)
data_final=data.loc[(z_score<3).all(axis=1)]
print(data_final.shape)
# Out:
# (178, 14)
# (170, 14)

# %%
data1=data.drop(columns=['Wine'])
x=data1
y=data['Wine']

# %%
max_score=0

for r_state in range(37,101):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.22,random_state=r_state)
    lg=LogisticRegression()
    lg.fit(x_train,y_train)
    pred=lg.predict(x_test)
    score=accuracy_score(y_test,pred)
    print("Accuracy Score: ",score,"at random state: ",r_state)
    if score>max_score:
        max_score=score
        final_r_state=r_state
print("Maximimum Accuracy Score is",max_score,'at',final_r_state)
# Out:
# Accuracy Score:  1.0 at random state:  37
# Accuracy Score:  1.0 at random state:  38
# Accuracy Score:  1.0 at random state:  39
# Accuracy Score:  0.95 at random state:  40
# Accuracy Score:  0.95 at random state:  41
# Accuracy Score:  0.975 at random state:  42
# Accuracy Score:  1.0 at random state:  43
# Accuracy Score:  0.975 at random state:  44
# Accuracy Score:  1.0 at random state:  45
# Accuracy Score:  0.95 at random state:  46
# Accuracy Score:  0.95 at random state:  47
# Accuracy Score:  1.0 at random state:  48
# Accuracy Score:  0.975 at random state:  49
# Accuracy Score:  0.975 at random state:  50
# Accuracy Score:  0.975 at random state:  51
# Accuracy Score:  0.95 at random state:  52
# Accuracy Score:  0.975 at random state:  53
# Accuracy Score:  1.0 at random state:  54
# Accuracy Score:  0.975 at random state:  55
# Accuracy Score:  1.0 at random state:  56
# Accuracy Score:  1.0 at random state:  57
# Accuracy Score:  0.95 at random state:  58
# Accuracy Score:  1.0 at random state:  59
# Accuracy Score:  1.0 at random state:  60
# Accuracy Score:  0.975 at random state:  61
# Accuracy Score:  0.95 at random state:  62
# Accuracy Score:  0.95 at random state:  63
# Accuracy Score:  1.0 at random state:  64
# Accuracy Score:  0.975 at random state:  65
# Accuracy Score:  1.0 at random state:  66
# Accuracy Score:  0.9 at random state:  67
# Accuracy Score:  1.0 at random state:  68
# Accuracy Score:  1.0 at random state:  69
# Accuracy Score:  1.0 at random state:  70
# Accuracy Score:  0.95 at random state:  71
# Accuracy Score:  0.875 at random state:  72
# Accuracy Score:  0.925 at random state:  73
# Accuracy Score:  0.925 at random state:  74
# Accuracy Score:  0.975 at random state:  75
# Accuracy Score:  0.975 at random state:  76
# Accuracy Score:  0.975 at random state:  77
# Accuracy Score:  1.0 at random state:  78
# Accuracy Score:  1.0 at random state:  79
# Accuracy Score:  0.975 at random state:  80
# Accuracy Score:  1.0 at random state:  81
# Accuracy Score:  0.925 at random state:  82
# Accuracy Score:  1.0 at random state:  83
# Accuracy Score:  0.975 at random state:  84
# Accuracy Score:  0.975 at random state:  85
# Accuracy Score:  0.95 at random state:  86
# Accuracy Score:  0.975 at random state:  87
# Accuracy Score:  1.0 at random state:  88
# Accuracy Score:  0.925 at random state:  89
# Accuracy Score:  0.95 at random state:  90
# Accuracy Score:  1.0 at random state:  91
# Accuracy Score:  0.95 at random state:  92
# Accuracy Score:  0.975 at random state:  93
# Accuracy Score:  0.975 at random state:  94
# Accuracy Score:  0.95 at random state:  95
# Accuracy Score:  1.0 at random state:  96
# Accuracy Score:  0.95 at random state:  97
# Accuracy Score:  1.0 at random state:  98
# Accuracy Score:  0.975 at random state:  99
# Accuracy Score:  1.0 at random state:  100
# Maximimum Accuracy Score is 1.0 at 37

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=37,test_size=0.22)

# %%
lg=LogisticRegression()
lg.fit(x_train,y_train)
pred=lg.predict(x_test)
print("Accuracy Score: ",accuracy_score(y_test,pred))
print('\n')
print('Confusion Matrix',confusion_matrix(y_test,pred))
print('\n')
print('classification report',classification_report(y_test,pred))
# Out:
# Accuracy Score:  1.0
#
#
# Confusion Matrix [[14  0  0]
#  [ 0 15  0]
#  [ 0  0 11]]
#
#
# classification report               precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        14
#            2       1.00      1.00      1.00        15
#            3       1.00      1.00      1.00        11
#
#     accuracy                           1.00        40
#    macro avg       1.00      1.00      1.00        40
# weighted avg       1.00      1.00      1.00        40

# %%
#cross validation

from sklearn.model_selection import cross_val_score

scores=cross_val_score(lg,x,y,cv=5)
print(scores)
print(scores.mean(),scores.std())
# Out:
# [0.83333333 1.         0.88888889 1.         1.        ]
# 0.9444444444444444 0.07027283689263066

# %%
# saving the model

import joblib
joblib.dump(lg,'wine.pkl')
# Out:
# ['wine.pkl']
